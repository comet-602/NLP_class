# %%
# !python --version
# Out:
# Python 3.7.4

# %%
# !pip install -q -U pip
# !pip install -q numpy
# !pip install -q pandas
# !pip install -q ckiptagger
# !pip install -q tqdm
# !pip install -q tensorflow==1.14.0
# !pip install -q ipywidgets

# %%
import pandas as pd
import numpy as np

from ckiptagger import WS, POS
from tqdm.notebook import tqdm

# %%
df_train = pd.read_csv('news_clustering_train.tsv', sep='\t')
df_test = pd.read_csv('news_clustering_test.tsv', sep='\t')

# %%
df_train
# Out:
#       index class                            title
# 0         0    體育         亞洲杯奪冠賠率：日本、伊朗領銜 中國竟與泰國並列
# 1         1    體育        9輪4球本土射手僅次武磊 黃紫昌要搶最強U23頭銜
# 2         2    體育             如果今年勇士奪冠，下賽季詹姆斯何去何從？
# 3         3    體育            超級替補！科斯塔本賽季替補出場貢獻7次助攻
# 4         4    體育          騎士6天里發生了啥？從首輪搶七到次輪3-0猛龍
# ...     ...   ...                              ...
# 1795   1795    遊戲  LOL：麻辣香鍋韓服Rank不合成打野刀？電刀巨魔新套路連勝中
# 1796   1796    遊戲            穩住，我們能贏！因為我們擁有這種強大的力量
# 1797   1797    遊戲          騰訊是怎樣毀掉《鬥戰神》這款可能成神的作品的？
# 1798   1798    遊戲                   LOL你不知道的黑科技打法！
# 1799   1799    遊戲                 遊戲拳皇各代的劇情都在講些什麼？
#
# [1800 rows x 3 columns]

# %%
train_titles = {row['index']: row['title'] for _, row in df_train.iterrows()}
train_classes = {row['index']: row['class'] for _, row in df_train.iterrows()}

test_titles = {row['index']: row['title'] for _, row in df_test.iterrows()}
test_classes = {row['index']: row['class'] for _, row in df_test.iterrows()}

# %%
all_news_class = ['體育', '財經', '科技', '旅遊', '農業', '遊戲']

# %% [markdown]
# # 斷詞 + POS

# %%
ws = WS('./data')
pos = POS('./data')

# %%
train_title_cuts = {}
for index, title in tqdm(train_titles.items()):
    # YOUR CODE HERE
    word_s = ws([title])
    word_p = pos(word_s)
    # END YOUR CODE
    train_title_cuts[index] = list(zip(word_s[0], word_p[0]))
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=1800.0), HTML(value='')))

# %%
test_title_cuts = {}
for index, title in tqdm(test_titles.items()):
    # YOUR CODE HERE
    word_s = ws([title])
    word_p = pos(word_s)
    # END YOUR CODE
    test_title_cuts[index] = list(zip(word_s[0], word_p[0]))
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=600.0), HTML(value='')))

# %%
train_title_cuts[120]
# Out:
# [('國腳', 'Na'),
#  ('張呈棟', 'Nb'),
#  ('：', 'COLONCATEGORY'),
#  ('從', 'D'),
#  ('沒', 'D'),
#  ('想', 'VE'),
#  ('過', 'Di'),
#  ('自己', 'Nh'),
#  ('會', 'D'),
#  ('出', 'VC'),
#  ('一', 'Neu'),
#  ('本', 'Nf'),
#  ('書', 'Na')]

# %% [markdown]
# # Bag of Words (BOW)

# %%
word2index = {}
index2word = {}
# 產生字與index對應的關係
# YOUR CODE HERE
n = 0
for index in train_title_cuts:
    for word, flag in train_title_cuts[index]:
        if word in word2index:
            continue
        word2index[word] = n 
        index2word[n] = word
        n += 1
# END YOUR CODE

# %%
word2index['溫暖']
# Out:
# 1520

# %%
index2word[1520]
# Out:
# '溫暖'

# %%
def get_bow_vector(pairs, word2index):
    # YOUR CODE HERE
    vector = np.zeros(len(word2index))
    for word, flag in pairs:
        if word in word2index:
            vector[word2index[word]] += 1
    # END YOUR CODE
    return vector

# %%
get_bow_vector(train_title_cuts[120], word2index)
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %% [markdown]
# # 排除較無意義的詞性

# %%
pos_analysis = {}
for _, pairs in train_title_cuts.items():
    for word, flag in pairs:
        if flag not in pos_analysis:
            pos_analysis[flag] = set()
        pos_analysis[flag].add(word)

for flag, words in pos_analysis.items():
    print(flag, ':', list(words)[:100])
    print('=======================')
# Out:
# Nb : ['扎哈維', '璞麗', '新游', '詹姆斯', '董明珠', '靜懿', '娜迦王海伯倫', '微眾', '馬夏爾', '萊昂納德', '周雲傑', '李暉', '密子君', '朱之文', '周評', '王', '精准', '劉國梁', '寶二', '卡拉黑', '卡帥', '星巴克', '雷軍', '殺里', '重渡溝', '瓦基弗', '刷安徒恩', '美年達', '泰森', '趙雲', '伊亞', '沙特', '藍星', '里皮', '凱西', '大美', '李大霄', '張', '劉詩雯', '德比', '張藝謀', '梅西納', '招行', '陶華碧', '王楚欽', '小明', '林美景', '安永', '波爾', '權健', '濃眉哥', '盧', '伯克希爾', '劉偉', '英特爾', '微醫', '小強', '王昭君', '施泰納', '姆巴佩', '微博', '萊萬特', '奧恰洛夫', '劉歡', '海富通', '京新', 'WWE', '阿里舜宇', '埃梅里', '凱爾特', '張某', '雪迪龍', '戈麥斯', '余則成', '東決', '建成', '李白界', '德帥', '姚勁波', '巴菲特', '索尼', '姚振華', '切沃', '魯能', '龔方雄', '天貓', '后羿', '吳敬璉', '張良咸', '西蒙斯', '武磊', '拉基蒂奇', '盼保', '劉德華', '朱嘯虎', 'S10', '何享健', '昂科威', '斯威', '阿里']
# =======================
# VC : ['斬落', '等到', '替補', '宣一', '養成', '戰釀', '奪', '投入', '秀', '抽到', '編程', '贊取', '搞', '激勵', '買賣', '作', '零售', '約', '扒出', '使用', '指導', '融合', '養', '禁', '爭', '補', '表演', '噴', '推出', '收購', '踐行', '打通', '碰到', '尋', '打死', '前瞻', '刺激', '對付', '娶', '掙到', '寫', '雙殺', '揭秘', '上', '嫁', '團購', '投身', '加盟', '控制', '扔上', '清理', '添脫', '秒選', '合併', '接', '帶動', '記', '淘汰', '問倒', '啓定', '對待', '保留', '逼瘋', '拍攝', '看完', '完虐', '縮減', '春栽', '直播', '攀爬', '表揚', '吃好', '解決', '強攻', '留下', '打破', '鋪開', '保存', '靠近', '實現', '雷劈', '論', '動用', '堆上', '造就', '集中', '攀比', '支援', '催收', '評論', '登記', '審查', '打野', '套養', '出口', '花用', '開復', '單殺', '詮釋', '重建']
# =======================
# Na : ['女乒', '國腳', '小組賽', '武器', '智力', '夢', '空單', '秀', '高效', '夢想', '風潮', '穗期', '田水', '民航機', '部長', '取款機', '野味', '電量', '藥劑', '記者', '均線', '生死', '新星', '富豪', '綜合體', '辦法', '陝西人', '經濟', '話', '射手', '素質', '收入', '保級', '米體', '魂', '玉米稈', '維碼', '小麥孕', '金', '賽事', '獸藥', '現金', '預警', '股份', '幣圈', '軸', '指標', '蛋樹', '黑客', '霸氣', '魔', '蠱', '四維', '說纏', '啓程', '耗電量', '龍蝦', '上單', '軟件', '收款碼', '人物', '社交', '妖精', '木材', '花崗岩', '人士', '英雄級', '銀聯卡', '地確權', '形態', '地方', '要點', '大盤點', '牙', '跆拳道', '方向', '白鰱', '飛車', '大關', '損害', '訴訟費', '氣候', '東西', '大火', '任務', '利好', '規範', '單位', '運動員', '大水', '概要', '傷害', '草原', '領路人', '嘲諷度', '片花', '百里玄策', '文', '貿易', '病蟲害']
# =======================
# COLONCATEGORY : [':', '：']
# =======================
# Nc : ['黑龍江', '重慶', '國際', '工廠', '馬刺', '天堂', '平橋鄉', '眼前', '煙台', '柯橋', '大理', '游景點', '九龍', '五一', '保監會', '華池縣', '秘境', '東京', '盱眙', '巴西', '三亞', '冰城', '黃土高原', '歐洲', '珠寶店', '賽場', '校', '麻城', '泰安', '冠豸山', '潘帕斯', '黃鶴樓', '西安比', '去處', '國安會', '昆明', '大縣', '球館', '吉隆坡', '雜貨鋪', '湘西', '民族鄉', '北侖', '鵬城', '莊浪', '波密', '火鍋店', '優區', '以色列', '阜南縣', '舟山', '延邊', '江蘇', '四川', '富縣', '免稅店', '奧蘭多', '蒼山', '交界', '高空', '國', '光明路', '自駕游', '梅縣', '古鎮', '宅', '招行', '天津', '波蘭', '北宅', '上海', '基地', '華僑城', '內內', '影視城', '全球', '果嶺', '聖托里尼亞', '中行', '港', '莊家', '銀行', '宿城', '烏衣巷口', '滕州', '中國', '金融城', '石鼓園', '德國', '世界', '瑞典', '鹽城', '嶗山', '呼倫貝爾', '洗車店', '北川', '大陸', '青島鄉', '蕩漾湖', '火焰山']
# =======================
# PAUSECATEGORY : ['、']
# =======================
# VB : ['退貨', '拍照', '護航', '退款', '騙錢', '計算出來', '提前', '領銜', '加起來', '收回來', '扣分', '解密', '助威', '一網打盡', '加工', '加冕', '分段', '鋪平', '代打', '開戰', '加持', '解體', '解惑', '應對', '分紅', '鍍金', '定位', '罰款', '復仇', '相比', '退改', '導航', '效力', '融資', '罵屌絲', '抓來', '分組', '通話', '再見', '執教', '充氣', '站台', '解圍', '充飢', '加油', '入賬', '上架']
# =======================
# WHITESPACE : [' ']
# =======================
# D : ['需', '正在', '略', '首次', '獨', '大都', '超級', '反野', '已經', '這麼', '交互', '及時', '突然', '不應該', '或許', '首先', '難道', '互相', '不要', '隨地', '完全', '可能', '不能', '現', '始', '就', '直', '均', '那麼', '經常', '所', '玩絕', '時刻', '將', '仍然', '逐漸', '不會', '可否', '能', '得', '自然', '會', '立即', '曾', '還', '互', '趕緊', '應該', '來', '可', '大概', '攜手', '天南地北', '該不該', '同', '屢屢', '屢', '沒有', '已然', '多多少少', '真', '從', '聯合', '老是', '不用', '吃起來', '年年', '大幅', '曾經', '不再', '差點兒', '好像', '卻', '還是', '終於', '每', '常', '還可以', '差點', '趁早', '呼好', '驟然', '未必', '總算', '怎樣', '盡情', '不', '其實', '非', '該', '竟然', '隨時', '預先', '首', '越', '接著', '會不會', '專職', '快', '必須']
# =======================
# P : ['為了', '距離', '在', '跟', '慘遭', '把', '於', '自', '給', '到', '當', '至', '除', '往', '和', '趁', '繼', '與', '比', '關於', '自從', '以', '向', '對', '遭', '臨', '憑', '就', '根據', '將', '像', '靠', '為', '離', '針對', '按', '隨', '待', '被', '直至', '幫', '除了', '趁著', '比如', '因', '隨了', '如', '受', '等', '用', '從']
# =======================
# VG : ['做成', '戰成', '屈居', '等於', '稱', '似', '充當', '升任', '排行', '應聘', '排名', '當', '屬於', '誤認成', '做', '封號', '算', '疑似', '化', '當成', '理解為', '譽為', '稱為', '排', '叫', '投票成', '並列', '姓', '成', '非', '美成', '竟是', '彷彿', '賣成', '名叫', '猶如', '叫做', '堪稱', '像', '集成', '為', '成為', '形成', '當上', '變成', '當作', '酷似', '算是', '居', '類似', '稱作', '稱得上', '作為', '合成', '改造成', '建成', '如', '變', '評選']
# =======================
# Neu : ['第二', '500萬', '300', '3000', '10010', '85', '萬億', '五', '6', '4.7億', '3-0', '29', '20億', '四', '35萬', '50多', '2018千', '2200', '400', '5050', '五一', '450億', '千', '8', '72', '三百', '700', '三', '60多', '0:3', '14', '3100', '318', '零', '9-1', '12', '392億', '1699', '2000', '200', '20萬', '4000萬', '1300萬', '1300', '第五', '3:2', '80', '0', '1900億', '第9', '百億', '二〇三', '25', '千千萬', '42', '3000億', '47', '4', '第四十四', '百', '第三', '9-0', '5.5', '60', '第四', '835', '0:0', '十幾', '4萬多', '00', '17', '15.60', '2018.', '3000萬', '幾', '010', '2018', '6800', '2000萬', '7300', '第一', '715', '第3', '1', '115', '11.59億', '十六', '0-', '2018-05-06 ', '50萬', '9', '千億', '18', '2:1', '三千億', '54', '3', '16', '2', '1.3萬']
# =======================
# Nf : ['刻', '個', '港元', '天', '番', '掛', '檔', '局', '株', '鍋', '位', '班', '次', '斤', '頓', '美元', '所', '方', '分鐘', '年', '日', '屆', '名', '樣', '畝', '筆', '毛', '噸', '只', '元', '胎', '公里', '度', '歲', '把', '道', '門', '周', '件', '色', '串', '期', '種', '號', '張', '批', '些', '晚', '袋', '句', '關', '級', '棵', '台', '行', '類', '碗', '路', '座', '支', '頁', '戶', '輛', '頭', '部', '點', '塊', '口', '英吋', '遍', '條', '盤', '本', '場', '家', '隊', '股', '套', '秒', '篇', '節', '片', 'K', '週', '票', '對', '招', '群', '回', '層', '處', '分', '輪', '則', '米', '款', '槍', '隻', '項', '步']
# =======================
# VJ : ['看懂', '嫌棄', '失去', '贏得', '平', '值', '熱心', '新增', '贊同', '領略', '大勝', '認', '強過', '吃上', '限', '分享', '不如', '得', '適應', '欣賞', '懷念', '偏愛', '領跑', '減', '超過', '輸掉', '歸屬於', '擁有', '沒有', '處於', '減持', '發揮', '含有', '遺傳', '心疼', '抗', '衝', '入圍', '領先', '要價', '沈迷', '爆發', '歡迎', '展望', '服', '近', '不到', '脫', '替代', '同情', '養有', '喪失', '缺', '優於', '毫無', '來自', '負於', '羨慕', '錯過', '懼怕', '出', '適用', '維持', '曝限', '看好', '順應', '無', '不理', '珍惜', '惜', '超', '恪守', '達', '共有', '痛失', '透', '忽視', '持有', '享受', '吸引', '晉級', '入選', '符合', '虧損', '關注', '僅次', '缺少', '靠', '逾', '耗', '忘懷', '僅次於', '忽略', '身臨', '失', '煥發', '納入', '受', '贏下', '翻倍']
# =======================
# VD : ['禁售', '貸款', '坑', '收費', '給', '送', '郵給', '補貼', '賣', '配', '寄予', '欠', '清繳', '貸', '提供', '借貸', '借', '速遞', '交付', '補繳', '發給', '拒賠', '發', '支付', '輸', '發放', '搶', '轉讓', '輸給', '還', '給予', '分', '傳', '白送', '售', '付', '供應', '予', '贏']
# =======================
# Dfa : ['過', '更為', '較', '超', '好', '同樣', '這麼', '最', '過於', '遠遠', '多', '不大', '有點', '比較', '遠', '頗', '越來越', '太', '很', '更', '有些', '如此', '還', '十分', '非常', '極', '還要']
# =======================
# VH : ['肺腑獨白', '多姿', '詹吹', '富奔', '曝光', '大', '強', '無緣', '逼格', '常見', '偽風口', '迷路', '濃', '高效', '巨大', '秀', '滑滑', '飽', '出局', '特殊', '主動', '凝重', '未果', '悠久', '自私', '病', '太少', '畢業', '倒閉', '一樣', '自豪', '呆呆', '壯觀', '蓄勢待發', '面世', '經濟', '悲壯', '乾淨', '古', '受害', '百出', '閃現', '全神貫注', '普通', '急', '眾包', '睡著', '唯美', '觸底', '重大', '酸', '安全', '不足', '自由', '快速', '減產', '出色', '靈活', '到期', '霸氣', '破產', '見分曉', '簡約', '清淨', '相生', '徹底', '果真如此', '重要', '強硬', '堅決', '紅', '開大', '發熱', '多彩', '罕見', '逾期', '狠', '如何', '無奈', '殘', '拔涼拔涼', '可行', '見底', '足', '濃郁', '無盡', '成年', '歡樂', '驚人', '古老', '受傷', '公正', '隨便', '實用', '有望', '怎麼樣', '怎麼', '勝利', '克劫', '重重']
# =======================
# Cbb : ['不過', '就算', '因為', '只要', '但', '既然', '如果', '而', '不管', '既', '雖然', '即使', '要是', '若', '跟著', '連', '另外', '縱使', '但是', '可是', '不如', '不僅', '並且', '只有', '因', '否則', '假如', '而是', '並', '不然', '還不如', '反而']
# =======================
# Nd : ['13點', '狗年', '現在', '季', '首日', '季度', '昨天', '15日', '週二', '明年', '2019年', '花季', '最後', '12日', '臨時', '隔年', '2020年', '下旬', '今日', '19年', '15年', '3月', '熱天', '米節', '一日', '一大早', '4月', '夏日', '相親節', '現代', '2018年', '8日', '1點', '當年', '2018', '夏天', '週一', '8月', '5號', '周', '晚清', '06日', '四月', '30號', '半夜', '最近', '後期', '短期', '晚間', '幾月份', '7號', '一下', '2018年度', '春', '明', '5.7日', '夏季', '夜', '秋季', '週末', '今夏', '-5', '文化節', '後', '明晚', '旅遊節', '春天', '中旬', '初夏', '如今', '近日', '5月', '何時', '當前', '同時', '31號', '三國', '大中', '月季', '永久', '6旬', '7日', '23日', '那時', '夏', '春季', '寒武紀', '五月', '後來', '雍正', '立夏', '今天', '2035年', '當時', '90年', '以後', '六', '旺季', '過去', '未來']
# =======================
# VA : ['遊玩', '報關', '換人', '離隊', '目不暇接', '讀書', '違規', '謝幕', '種地', '收尾', '挺進', '打團', '踏步', '聯通', '游', '開課', '探秘', '打麻將', '溢出', '打野刀', '備戰', '倒計', '擒敵', '奔馳', '遠行', '轉會', '鬥米', '競技', '旅行', '保級', '傳宗接代', '倒伏', '上場', '滑雪', '起飛', '抗詹', '揮刀', '封卡', '自駕游', '聚焦', '偷鯤', '奪冠', '露營', '開團', '放飛', '建功', '進城', '報名', '下山', '共贏', '日落', '追肥', '隨行', '代工', '入院', '生活', '帶隊', '吃飯', '撒沙', '翻身', '徵信', '換股', '流動', '降額', '遊園', '投訴', '轉農', '助攻', '步行', '自駕', '復盤', '刮風', '倒地', '搶七', '拼房', '開盤', '出欄', '下雪', '算卦', '跌', '面對面', '開王', '爬山', '炒股', '做生意', '出發', '保量', '充電', '娶妻', '爆錘', '開機', '看盤', '進貨', '減稅', '擾民', '何去何從', '點贊', '退', '報檢', '築底']
# =======================
# COMMACATEGORY : [',', '，']
# =======================
# Nes : ['本', '首', '何', '近', '各', '貴', '下', '前', '頭', '某', '後', '同', '上', '另', '該', '每']
# =======================
# QUESTIONCATEGORY : ['？']
# =======================
# EXCLAMATIONCATEGORY : ['！', '!']
# =======================
# Di : ['過', '個', '起來', '了', '著']
# =======================
# Nep : ['什麼', '這', '其中', '哪', '啥', '其', '此', '那']
# =======================
# Caa : ['和', '及', '跟', '或', '暨', '或是', 'VS', '到', '比', '與', '至', '或者', '又', '還是']
# =======================
# VCL : ['過', '栽進', '跌至', '前往', '在', '前來', '深入', '到', '穿越', '上', '遠離', '赴', '抵達', '進入', '住', '往', '重回', '登陸', '用於', '穿透', '走過', '度過', '存進', '路過', '橫掃', '出發到', '跌出', '留在', '到達', '入', '來到', '走進', '蒞臨', '回', '回歸', '升至', '玩遍', '去', '盤踞', '出', '重返', '退出', '進', '穿過', '暗渡', '走訪', '回到', '走到', '直達', '走下', '遊覽']
# =======================
# Neqa : ['個個', '其他', '一些', '30%', '1%', '四成', '不少', '部分', '一半', '許多', '多點', '這些', '6%', '67%', '其它', '有的', '那些', '三分之一', '一處處', '哪些', '多少', '步步', '所有', '多', '句句', '很多', '100%', '1/4', '10%', '12%', '9.89%', '80%', '大多', '更多', '15%', '全', '有些', '一切', '一點', '8%', '0.8%', '41.8%', '大多數', '20%', '遍', '大量', '半', '90%', '這麼多', '無數', '滴滴', '任何', '百分之八十']
# =======================
# Nh : ['她', '別人', '俺們', '他', '他們', '它', '人家', '你們', '雙方', '私人', '她們', '自身', '一方', '誰', '各自', '個人', '本人', '屌絲', '父子倆', '它們', '各位', '自己', '大家', '對方', '自我', '我', '小眾', '我們', '你', '您']
# =======================
# FW : ['+7', 'Uzi', 'CF', 'shou', 'P2P', 'CEO', 'S11', 'Hello ', 'mix2', 'iPad', '！DOTA2 MOD', 'Cotswolds', 'lol', 'N+1', 'A', ' + ', 'PS', 'Minecraft', 'TPP', 'DNF ', 'King James', 'EVO', 'MARVEL X', '<', 'BAT', '：AG', 'EOS', 'iPhone X', ' 秀', 'BTC', 'Nvidia', '-0', 'etc', 'MSCI', 'QM', 'adc', '4AM', 'LPL', 'steam', 'OPPO R', 'SSG', 'Brian Kelly', 'iPhone7', 'G+', '5G', '―', 'Lol里', 'G', '：BTC', 'SSR', 'CCR', 'cosplay', 'B', 'QDC', 'Focus', 'dota', 'RPG', 'PGM 0-1 SUP', 'U23', 'Xbox ', 'max2', 'AP', 'SIo', 'GoogleI/O2018', 'OV', 'C', 'GDP', 'UZI', 'Aloha', 'cpu', '8d', '>', 'MSI', 'IG', 'bad boy', 'SUP', 'qq', 'app', 'e', 'Alan', ' MDL', '5A', 'OMG', ' 樂', 'iPhone X Plus', 'LOL：', '2', 'CP', 'ADC', 'AIC', 'Khan', 'pro7', 'Pro', 'J', 'Credo', 'wifi', 'PPP', 'TT', 'Soloking', 'Kitty']
# =======================
# SHI : ['是', '像是']
# =======================
# VE : ['防止', '知詢', '查找', '想要', '想到', '慶祝', '判斷', '檢測', '確認', '以為', '發現', '鑒定', '承諾', '想起', '安排', '披露', '呼', '看到', '警惕', '廣播', '預測', '管', '想', '查', '揭曉', '公示', '允許', '精准', '介紹', '發誓', '預定', '反對', '聊', '談', '預計', '禁止', '查看', '回答', '宣佈', '傳聞', '算', '呼籲', '感嘆', '暗示', '自嘲', '預防', '講', '研究', '考慮', '申卡', '賭約', '看看', '盛贊', '報道', '商量', '見證', '限制', '見', '說明', '形容', '稱', '聽到', '設想', '看出', '公認', '猜', '想好', '准', '樂見', '探討', '訴說', '提', '發佈', '調研', '提到', '聯想', '討說', '問', '聽說', '證', '回顧', '深思', '預告', '做到', '炫耀', '公佈', '假設', '示範', '講解', '說', '證明', '認為', '見到', '估值', '爆料', '告訴', '預期', '看清楚', '聽', '探索']
# =======================
# DE : ['的', '之', '地', '得']
# =======================
# VHC : ['熱', '國際化', '增強', '穩定', '還原', '平衡', '冷卻', '停', '公開', '智能化', '加快', '現代化', '變動', '增加', '產生', '可憐', '溫暖', '恢復', '降低', '震驚', '普及', '肥', '開', '優化', '辛苦', '豐富', '陷', '強化', '減少', '愁壞', '增 ', '破', '淡化', '下來', '結束', '擴張', '暫停', '傷', '機構化', '縮小', '凍', '壞', '滿足', '增長', '煩', '告破', '團結', '規模化', '感動', '斷', '麻煩', '繁榮', '愁死']
# =======================
# Ng : ['中', '底', '以後', '上', '之下', '之後', '之上', '初', '內', '左右', '裡', '時', '之內', '以來', '以上', '下', '之外', '以下', '外', '之前', '般', '為止', '之中', '來', '前', '以外', '起', '後', '而言', '之間', '間']
# =======================
# VK : ['感覺到', '介意', '需', '願', '信', '懷疑', '放心', '欲', '感受', '知道', '同意', '不滿', '喜歡', '意想不到', '討厭', '怕', '恨', '回憶', '擔心', '肯定', '意外', '希望', '想見', '不忘', '期待', '奇怪', '需要', '有利於', '曲解', '遇', '知', '理解', '害怕', '確定', '恐', '忘記', '遺憾', '忘', '流傳', '覺得', '所謂', '盼', '注意', '瞭解', '堅持', '顯示', '懂', '指望', '感謝', '依賴', '懂得', '感覺', '明白', '願意', '覺', '意味', '面臨', '小心', '抱歉']
# =======================
# Ncd : ['中', '哪', '這裡', '那裡', '上', '畔', '底部', '哪下', '中間', '裡面', '旁邊', '東部', '一帶', '內', '東西部', '裡', '東方', '哪兒', '末端', '邊', '外面', '方', '中部', '北', '下', '以下', '外', '上方', '那邊', '西部', '兩旁', '對面', '西', '東', '哪裡', '上面', '當中', '間', '前沿']
# =======================
# A : ['中', '共同', '前置', '國產', '超', '小本', '多餘', '額外', '超級', '必備', '野生', '基礎', '重磅', '二手', '綜合', '原', '獨角', '唯一', '新興', '現役', '同一', '上上', '頭號', '非', '同等', '碧藍', '乒乓', '總', '雙', '真正', '基層', '火紅', '寶有', '單', '眾', '新一代', '優質', '一般', '高度', '大幅度', '業餘', '主', '最佳', '現行', '獨家', '長途', '常務', '彩色', '歐式', '獨門', '麻辣', '後置', '地下', '中西']
# =======================
# V_2 : ['有']
# =======================
# VL : ['故意', '敢', '令', '趨於', '讓', '使得', '持續', '喜好', '用來', '開始', '後悔', '肯', '甘願', '導致', '能', '便利', '致', '愛好', '使', '愛', '習慣', '不惜']
# =======================
# T : ['哦', '麼', '咯', '啊', '來', '哪', '啦', '了', '矣', '吧', '呢', '的', '去', '嗎', '嘛']
# =======================
# VI : ['驚艷', '專用', '傾心', '著稱', '取勝']
# =======================
# DASHCATEGORY : ['-', '—']
# =======================
# I : ['哦', '瑪法里奧']
# =======================
# Dk : ['反過來', '那麼', '結果', '那', '據聞', '據說', '想不到', '外傳']
# =======================
# VF : ['止住', '拒絕', '申請', '圖', '告誡', '策劃', '拒', '停止', '助', '擬', '率領', '鼓勵', '叫', '推選', '勸住', '打算', '帶領', '試', '邀', '請', '催', '要求', '勸說', '逼', '準備', '繼續', '試試', '判']
# =======================
# Da : ['不下', '幾乎', '正好', '僅', '光', '近', '共', '只', '最多', '約', '幾近', '才', '足足', '唯獨', '將近']
# =======================
# PARENTHESISCATEGORY : ['「', '）', '(', '（', '」', '《', '》']
# =======================
# Nv : ['推薦', '思考', '營銷', '解救', '分銷', '代理', '供電', '經歷', '買單', '灌籃', '燃燒', '創業', '翻譯', '批發', '工作', '抗戰', '護髮', '管理', '崩潰', '射擊', '訴訟', '體驗', '旅遊', '銷售', '遊樂', '惡搞', '關聯', '研究', '度假', '生產', '回歸', '增發', '兼職', '開發', '錄制', '絕殺', '判罰', '疊加', '組合', '問', '航海', '輔助', '登山', '私募', '防治', '配置']
# =======================
# PERIODCATEGORY : ['。', '·']
# =======================
# VAC : ['集合', '移動', '推進', '動', '蒸發', '上演']
# =======================
# Dfb : ['些', '極了', '一點']
# =======================
# Cab : ['等等', '等']
# =======================
# SEMICOLONCATEGORY : ['；']
# =======================
# Neqb : ['多', '幾', '半', '以上']
# =======================
# ETCCATEGORY : ['…']
# =======================
# Cba : ['的話']
# =======================
# DOTCATEGORY : ['.']
# =======================

# %% [markdown]
# |         Type        |     Description    |
# |:-------------------:|:------------------:|
# | A                   | 非謂形容詞         |
# | Caa                 | 對等連接詞         |
# | Cab                 | 連接詞，如：等等   |
# | Cba                 | 連接詞，如：的話   |
# | Cbb                 | 關聯連接詞         |
# | D                   | 副詞               |
# | Da                  | 數量副詞           |
# | Dfa                 | 動詞前程度副詞     |
# | Dfb                 | 動詞後程度副詞     |
# | Di                  | 時態標記           |
# | Dk                  | 句副詞             |
# | DM                  | 定量式             |
# | I                   | 感嘆詞             |
# | Na                  | 普通名詞           |
# | Nb                  | 專有名詞           |
# | Nc                  | 地方詞             |
# | Ncd                 | 位置詞             |
# | Nd                  | 時間詞             |
# | Nep                 | 指代定詞           |
# | Neqa                | 數量定詞           |
# | Neqb                | 後置數量定詞       |
# | Nes                 | 特指定詞           |
# | Neu                 | 數詞定詞           |
# | Nf                  | 量詞               |
# | Ng                  | 後置詞             |
# | Nh                  | 代名詞             |
# | Nv                  | 名物化動詞         |
# | P                   | 介詞               |
# | T                   | 語助詞             |
# | VA                  | 動作不及物動詞     |
# | VAC                 | 動作使動動詞       |
# | VB                  | 動作類及物動詞     |
# | VC                  | 動作及物動詞       |
# | VCL                 | 動作接地方賓語動詞 |
# | VD                  | 雙賓動詞           |
# | VF                  | 動作謂賓動詞       |
# | VE                  | 動作句賓動詞       |
# | VG                  | 分類動詞           |
# | VH                  | 狀態不及物動詞     |
# | VHC                 | 狀態使動動詞       |
# | VI                  | 狀態類及物動詞     |
# | VJ                  | 狀態及物動詞       |
# | VK                  | 狀態句賓動詞       |
# | VL                  | 狀態謂賓動詞       |
# | V_2                 | 有                 |
# |                     |                    |
# | DE                  | 的之得地           |
# | SHI                 | 是                 |
# | FW                  | 外文               |
# |                     |                    |
# | COLONCATEGORY       | 冒號               |
# | COMMACATEGORY       | 逗號               |
# | DASHCATEGORY        | 破折號             |
# | DOTCATEGORY         | 點號               |
# | ETCCATEGORY         | 刪節號             |
# | EXCLAMATIONCATEGORY | 驚嘆號             |
# | PARENTHESISCATEGORY | 括號               |
# | PAUSECATEGORY       | 頓號               |
# | PERIODCATEGORY      | 句號               |
# | QUESTIONCATEGORY    | 問號               |
# | SEMICOLONCATEGORY   | 分號               |
# | SPCHANGECATEGORY    | 雙直線             |
# | WHITESPACE          | 空白               |

# %%
def get_bow_vector_with_selection(pairs, word2index):
    excluded_flags = [
        # 根據以上列舉出來的文字以及詞性表，請列出想要排除的詞性
        # YOUR CODE HERE
        'Nh', 'Nep', 'Nes', 'DE', 'T', 'P', 'V_2', 'SHI',
        'Dfa', 'Dfb', 'Da', 'Di', 'Dk',
        'Caa', 'Cab', 'Cba', 'Cbb',
        'COLONCATEGORY', 'COMMACATEGORY', 'DASHCATEGORY', 'DOTCATEGORY', 'ETCCATEGORY', 'EXCLAMATIONCATEGORY',
        'PARENTHESISCATEGORY', 'PAUSECATEGORY', 'PERIODCATEGORY', 'QUESTIONCATEGORY', 'SEMICOLONCATEGORY',
        'SPCHANGECATEGORY', 'WHITESPACE'
        # END YOUR CODE
    ]
    vector = np.zeros(len(word2index))
    for word, flag in pairs:
        if word in word2index and flag not in excluded_flags:
            vector[word2index[word]] += 1
    return vector

# %% [markdown]
# # Cosine Similarity

# %%
def cosine_similarity(bow1, bow2):
    # YOUR CODE HERE
    len_bow1 = np.sqrt(np.sum(np.square(bow1)))
    len_bow2 = np.sqrt(np.sum(np.square(bow2)))
    similarity = np.sum(bow1 * bow2) / (len_bow1 * len_bow2)
    # END YOUR CODE
    return similarity

# %%
bow1 = get_bow_vector(train_title_cuts[100], word2index)
bow2 = get_bow_vector(train_title_cuts[130], word2index)
cosine_similarity(bow1, bow2)
# Out:
# 0.08703882797784893

# %%
train_title_cuts[100]
# Out:
# [('山東', 'Nc'),
#  ('魯能', 'Nb'),
#  ('有沒有', 'D'),
#  ('可能', 'D'),
#  ('拿到', 'VC'),
#  ('今年', 'Nd'),
#  ('的', 'DE'),
#  ('中', 'A'),
#  ('超', 'A'),
#  ('冠軍', 'Na'),
#  ('？', 'QUESTIONCATEGORY')]

# %%
train_title_cuts[130]
# Out:
# [('NBA', 'Nb'),
#  ('和', 'Caa'),
#  ('CBA', 'FW'),
#  ('差距', 'Na'),
#  ('在', 'P'),
#  ('哪裡', 'Ncd'),
#  ('？', 'QUESTIONCATEGORY'),
#  ('6', 'Neu'),
#  ('張', 'Nf'),
#  ('圖', 'VF'),
#  ('一目瞭然', 'VH'),
#  ('！', 'EXCLAMATIONCATEGORY')]

# %% [markdown]
# # Group mean vector

# %%
group_vectors = {news_class: [] for news_class in all_news_class}
for index, pairs in sorted(train_title_cuts.items()):
    vector = get_bow_vector_with_selection(pairs, word2index)
    news_class = train_classes[index]
    group_vectors[news_class].append(vector)

group_mean_vector = {}
for news_class, vectors in group_vectors.items():
    group_mean_vector[news_class] = np.mean(vectors, axis=0)
group_mean_vector
# Out:
# {'體育': array([0.04      , 0.01333333, 0.00333333, ..., 0.        , 0.        ,
#         0.        ]),
#  '財經': array([0., 0., 0., ..., 0., 0., 0.]),
#  '科技': array([0., 0., 0., ..., 0., 0., 0.]),
#  '旅遊': array([0., 0., 0., ..., 0., 0., 0.]),
#  '農業': array([0., 0., 0., ..., 0., 0., 0.]),
#  '遊戲': array([0.        , 0.        , 0.        , ..., 0.00333333, 0.00333333,
#         0.00333333])}

# %% [markdown]
# # Group mean vector: 測試

# %%
classification = {news_class: [] for news_class in all_news_class}
for index, pairs in sorted(test_title_cuts.items()):
    vector = get_bow_vector_with_selection(pairs, word2index)
    if np.sum(np.square(vector)) == 0:
        continue

    max_val = -2.0
    max_class = None
    for news_class, ref_vector in group_mean_vector.items():
        val = cosine_similarity(ref_vector, vector)
        if val > max_val:
            max_class = news_class
            max_val = val

    classification[max_class].append(index)

# %%
from collections import Counter

for group, ids in classification.items():
    counter = Counter([test_classes[id] for id in ids])
    print('predict', group, ': ', counter)
# Out:
# predict 體育 :  Counter({'體育': 73, '遊戲': 8, '財經': 6, '旅遊': 6, '農業': 6, '科技': 3})
# predict 財經 :  Counter({'財經': 67, '科技': 18, '體育': 6, '旅遊': 6, '遊戲': 6, '農業': 5})
# predict 科技 :  Counter({'科技': 62, '財經': 13, '體育': 10, '農業': 6, '遊戲': 6, '旅遊': 2})
# predict 旅遊 :  Counter({'旅遊': 70, '農業': 11, '財經': 6, '科技': 3, '遊戲': 2})
# predict 農業 :  Counter({'農業': 70, '旅遊': 9, '科技': 6, '體育': 5, '財經': 4, '遊戲': 3})
# predict 遊戲 :  Counter({'遊戲': 75, '科技': 7, '旅遊': 5, '體育': 4, '財經': 4, '農業': 1})
